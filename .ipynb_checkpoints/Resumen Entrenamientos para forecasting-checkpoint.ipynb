# %% [markdown]
# # Resumen de entrenamientos

# %% [markdown]
# ### Notas Importantes:
# > - En todos los modelos se usó un lag de 3, eso implica que se requieren al menos 3 filas (historial) de mediciones para todos los parámetros para poder construir la estructura que los modelos pueden leer.
#
# ### Librerías y versiones utilizadas
# > - `pandas`== 1.4.4
# > - `numpy` == 1.21.5
# > - `scikit-learn`==1.1.1.
# > - `statsmodels`==0.13.2
# > - `joblib`==1.1.0
# > - `matplotlib`==3.5.2
# > - `seaborn`==0.11.2
# > - `regex`==2022.7.9
# > - `glob2`==0.7
#
#
#
#
# <table style="border-collapse:collapse;border-spacing:0" class="tg"><thead><tr><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:middle;word-break:normal" rowspan="3">Modelo<br></th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="4">EColi</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="4">Turbiedad</th></tr><tr><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="2">Todas las localidades</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="2">Coyhaique </th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="2">Todas las localidades </th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:16px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="2">Coyhaique</th></tr><tr><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MAE</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MSE</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MAE</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MSE</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MAE</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MSE</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MAE</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">MSE</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Regresión Lineal (Regularizada con Ridge)</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">107.66</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">25598.45</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">194.18</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">146470.53</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">2.48</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">47.64</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">4.62</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">59.49</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">RandomForest</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">83.64</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">14511.28</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">184.21</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">140120.15</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">2.80</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">70.80</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">3.87</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">67.49</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">AdaBoost</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">86.86</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">19044.34</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">186.42</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">166925.56</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">2.05</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">55.19</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">3.19</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">65.33</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">XGBoost</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">66.26</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">6375.73</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">156.08</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">41118.11</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">3.91</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">114.78</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">5.16</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">12274</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">SARIMAX</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">65.92</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">10029.49</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">119.63</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">38970.78</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">3.96</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">118.70</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">4.23</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">120.48</td></tr></tbody></table>

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from glob import glob
import re
from sklearn.preprocessing import StandardScaler
from copy import copy

from data_preproc import *
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,7)
import seaborn as sn

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.linear_model import RidgeCV
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV

from statsmodels.tsa.stattools import ccf
from statsmodels.tsa.statespace.sarimax import SARIMAX

import warnings
warnings.filterwarnings('ignore')

from joblib import load, dump


param_grid_rf = {'n_estimators': [10,50,100,200], 'min_samples_split': [0.05, 0.1, 0.3, 0.5], 'max_depth':[10, 50, 100], 'min_samples_leaf':[0.01, 0.05, 0.1]}
param_grid_ada = {'estimator__n_estimators': [10,50,100,200], 'estimator__learning_rate': [0.5, 1.0, 1.5]}

# %% [markdown]
# ## Con data exógena (incluyendo temperatura y precipitaciones)

# %%
pr18_files = glob('modeloRiesgoAmbiental/DATOS INTERNOS TOTAL LOCALIDADES/Historial PR18-2 Muestras/*.csv')
pr18 = pd.concat([pd.read_csv(file, index_col=0) for file in pr18_files], axis = 0) # Estas dos lineas son reemplazables por otra forma de ingesta de esta info

precip_file_paths = glob('precip_data/diarias/CR2/*.xlsx')
temp_file_paths = glob('temperaturasMedias/diarias/CR2/*.xlsx')

localidad_re = re.compile(r'/(\w+)_\w+_\w+\.xlsx')
codigoLocalidad_dict = {'Coyhaique': 82, 'PuertoChacabuco': 255, 'PuertoCisnes': 256, 'Balmaceda': 22, 'PuertoAysen': 254, 'Cochrane': 62,
    'PuertoIbanez': 257, 'ChileChico': 55}

df_precipitaciones = pd.DataFrame(pd.concat([getDataFrame_from_CR2Source(file_path, 'precipitacion') for file_path in precip_file_paths], axis = 0))
df_precipitaciones.drop(columns = ['codigoLocalidad'], inplace = True)
df_temperaturas = pd.DataFrame(pd.concat([getDataFrame_from_CR2Source(file_path, 'temperatura') for file_path in temp_file_paths], axis = 0))
df_temperaturas.drop(columns = ['codigoLocalidad'], inplace =True)

# %%
proc_data = full_preproc_exgenas(pr18, df_precipitaciones, df_temperaturas)

# %% [markdown]
# # E-COLI

# %%
tain_test_format_results = generate_train_test(proc_data, target_col = 'E-COLI')
x_train, x_test, y_train, y_test = tain_test_format_results['data']
scaler = tain_test_format_results['std_scaler']

# %%
y_test.index.max()
# Out:
# Timestamp('2022-06-27 00:00:00')

# %%
#dump(scaler, 'modelos/ecoli_scaler_general.joblib')
# Out:
# ['modelos/ecoli_scaler_general.joblib']

# %% [markdown]
# ## Regresión lineal - Regularizada con Ridge

# %%
linreg_ridge = RidgeCV(cv = 5).fit(x_train, y_train)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de Regresión Lineal para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = linreg_ridge.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, linreg_ridge.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, linreg_ridge.predict(x_test))}')
# Out:
# MAE:107.66280747333433
# MSE: 25598.451768269646

# %%
dump(value = linreg_ridge, filename = 'modelos/ecoli_linreg_general.joblib');

# %% [markdown]
# ## RandomForest

# %%
# %%time
rf = GridSearchCV(RandomForestRegressor(n_jobs = -1), cv = 10, param_grid = param_grid_rf).fit(x_train, y_train).best_estimator_
# Out:
# CPU times: user 1min 36s, sys: 11 s, total: 1min 47s
# Wall time: 1min 48s

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de RandomForest para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = rf.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo RandomForest', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, rf.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, rf.predict(x_test))}')
# Out:
# MAE:83.63651146371178
# MSE: 14511.281172382944

# %%
dump(value = rf, filename = 'modelos/ecoli_rf_general.joblib');

# %% [markdown]
# ## AdaBoost

# %%
#ada = MultiOutputRegressor(AdaBoostRegressor(), n_jobs = -1)
ada = GridSearchCV(MultiOutputRegressor(AdaBoostRegressor(), n_jobs = -1), cv = 10, param_grid = param_grid_ada).fit(x_train, y_train).best_estimator_

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de AdaBoost para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = ada.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo AdaBoost', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, ada.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, ada.predict(x_test))}')
# Out:
# MAE:86.85962948325505
# MSE: 19044.344065402758

# %%
#dump(value = ada, filename = 'modelos/ecoli_adaboost_general.joblib');

# %% [markdown]
# ## XGBoost

# %%
xgboost = MultiOutputRegressor(xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 10, n_estimators = 100), n_jobs = -1)

# %%
xgboost.fit(x_train, y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(alpha=10, base_score=None,
#                                             booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.3,
#                                             enable_categorical=False,
#                                             gamma=None, gpu_id=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.1,
#                                             max_delta_step=None, max_depth=10,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
# ...

# %%
xgboost = load('modelos/ecoli_xgboost_general.joblib')

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de XGBoost para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = xgboost.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo XGBoost', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
plt.ylabel('E-COLI')
plt.xlabel('Fecha (Agregación semanal)')
sn.despine()
plt.savefig('img/resultados/xgboost_general_ecoli.png')

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
print(f'MSE: {mean_squared_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
# Out:
# MAE:66.26003447941372
# MSE: 6375.727559241005

# %%
#dump(value = xgboost, filename = 'modelos/ecoli_xgboost_general.joblib');

# %% [markdown]
# ## SARIMAX

# %%
ar_order = [1]
ma_order = [2]

diff_order = 1
test_size = 12

# %%
# %time

exog_series = x_train
endog_series = y_train.lag_0
rolling_predictions = []
test_size = 12

#for i in range(test_size):
#    exog_train = exog_series[:-(test_size-i)]
#    endog_train = endog_series[:-(test_size-i)]
#    model = SARIMAX(endog = endog_train, exog = exog_train ,order = (ar_order, diff_order, ma_order))
#    model_fit = model.fit(disp = False)
#    pred = model_fit.forecast(exog = exog_train[-1, :])# + res.seasonal[-1:].values
#    rolling_predictions.append(pred.values[0])#.append(np.sqrt(pred.variance.values[-1,:][0]))
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.01 µs

# %%
sarimax = SARIMAX(endog = y_train.lag_0.iloc[-3:], exog = x_train[-3:, :] ,order = (ar_order, diff_order, ma_order))
sarimax_fit = sarimax.fit(disp = False)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de SARIMAX para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True).to_numpy(), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data =  sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy(), color = 'darkgreen', label = 'Predicciones Modelo SARIMAX', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
print(f'MSE: {mean_squared_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
# Out:
# MAE:65.9191862165368
# MSE: 10029.49143734305

# %%
dump(value = sarimax_fit, filename = 'modelos/ecoli_SARIMAX_general.joblib');

# %% [markdown]
# ------

# %% [markdown]
# # Turbiedad

# %%
tain_test_format_results = generate_train_test(proc_data, target_col = 'TURBIEDAD')
x_train, x_test, y_train, y_test = tain_test_format_results['data']
scaler = tain_test_format_results['std_scaler']

# %%
#dump(scaler, 'modelos/turbiedad_scaler_general.joblib')
# Out:
# ['modelos/turbiedad_scaler_general.joblib']

# %% [markdown]
# ## Regresión lineal - Regularizada con Ridge

# %%
linreg_ridge = RidgeCV(cv = 5).fit(x_train, y_train)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de Regresión Lineal para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = linreg_ridge.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, linreg_ridge.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, linreg_ridge.predict(x_test))}')
# Out:
# MAE:2.4835393396006515
# MSE: 47.63776353003257

# %%
dump(value = linreg_ridge, filename = 'modelos/turbiedad_linreg_general.joblib');

# %% [markdown]
# ## RandomForest

# %%
rf = GridSearchCV(RandomForestRegressor(n_jobs = -1), cv = 10, param_grid = param_grid_rf).fit(x_train, y_train).best_estimator_

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de RandomForest para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = rf.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, rf.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, rf.predict(x_test))}')
# Out:
# MAE:2.796833851263594
# MSE: 70.7982391283396

# %%
#dump(value = rf, filename = 'modelos/turbiedad_rf_general.joblib');

# %% [markdown]
# ## AdaBoost

# %%
ada = GridSearchCV(MultiOutputRegressor(AdaBoostRegressor(), n_jobs = -1), cv = 10, param_grid = param_grid_ada).fit(x_train, y_train).best_estimator_

# %%
ada = load('modelos/turbiedad_ada_general.joblib')

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de AdaBoost para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = ada.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine()
plt.xlabel('Fecha')
plt.ylabel('Turbiedad')
plt.savefig('img/resultados/adaboost_general_turbiedad.png')

# %%
print(f'MAE:{mean_absolute_error(y_test, ada.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, ada.predict(x_test))}')
# Out:
# MAE:2.054102531926267
# MSE: 55.1928375587419

# %%
#dump(value = ada, filename = 'modelos/turbiedad_ada_general.joblib');

# %% [markdown]
# ## XGBoost

# %%
xgboost = MultiOutputRegressor(xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 10, n_estimators = 100), n_jobs = -1)

# %%
xgboost.fit(x_train, y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(alpha=10, base_score=None,
#                                             booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.3,
#                                             enable_categorical=False,
#                                             gamma=None, gpu_id=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.1,
#                                             max_delta_step=None, max_depth=10,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
# ...

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de XGBoost para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = xgboost.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
print(f'MSE: {mean_squared_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
# Out:
# MAE:3.9105061136067856
# MSE: 114.77643953187122

# %%
dump(value = xgboost, filename = 'modelos/turbiedad_xgboost_general.joblib');

# %% [markdown]
# ## SARIMAX

# %%
ar_order = [1]
ma_order = [2]

diff_order = 1
test_size = 12

# %%
# %time

exog_series = x_train
endog_series = y_train.lag_0
rolling_predictions = []
test_size = 12

#for i in range(test_size):
#    exog_train = exog_series[:-(test_size-i)]
#    endog_train = endog_series[:-(test_size-i)]
#    model = SARIMAX(endog = endog_train, exog = exog_train ,order = (ar_order, diff_order, ma_order))
#    model_fit = model.fit(disp = False)
#    pred = model_fit.forecast(exog = exog_train[-1, :])# + res.seasonal[-1:].values
#    rolling_predictions.append(pred.values[0])#.append(np.sqrt(pred.variance.values[-1,:][0]))
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs

# %%
sarimax = SARIMAX(endog = y_train.lag_0.iloc[-3:], exog = x_train[-3:, :] ,order = (ar_order, diff_order, ma_order))
sarimax_fit = sarimax.fit(disp = False)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de SARIMAX para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True).to_numpy(), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data =  sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy(), color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
print(f'MSE: {mean_squared_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
# Out:
# MAE:3.9558351583951197
# MSE: 118.70314181003208

# %%
dump(value = sarimax_fit, filename = 'modelos/turbiedad_SARIMAX_general.joblib');

# %% [markdown]
# ---------
#
# # Modelo para Coyhaique

# %%
data_coyhaique = pr18[pr18['codigoLocalidad'] == codigoLocalidad_dict['Coyhaique']]

df_precipitaciones = pd.DataFrame(pd.concat([getDataFrame_from_CR2Source(file_path, 'precipitacion') for file_path in precip_file_paths], axis = 0))
df_precipitaciones = df_precipitaciones[df_precipitaciones['codigoLocalidad'] == codigoLocalidad_dict['Coyhaique']]
df_precipitaciones.drop(columns = ['codigoLocalidad'], inplace = True)

df_temperaturas = pd.DataFrame(pd.concat([getDataFrame_from_CR2Source(file_path, 'temperatura') for file_path in temp_file_paths], axis = 0))
df_temperaturas = df_temperaturas[df_temperaturas['codigoLocalidad'] == codigoLocalidad_dict['Coyhaique']]
df_temperaturas.drop(columns = ['codigoLocalidad'], inplace =True)

# %%
proc_data = full_preproc_exgenas(data_coyhaique, df_precipitaciones, df_temperaturas)

# %% [markdown]
# # E-COLI

# %%
tain_test_format_results = generate_train_test(proc_data, target_col = 'E-COLI')
x_train, x_test, y_train, y_test = tain_test_format_results['data']
scaler = tain_test_format_results['std_scaler']

# %%
#dump(scaler, 'modelos/ecoli_scaler_coyhaique.joblib')
# Out:
# ['modelos/ecoli_scaler_coyhaique.joblib']

# %% [markdown]
# ## Regresión lineal - Regularizada con Ridge

# %%
linreg_ridge = RidgeCV(cv = 5).fit(x_train, y_train)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de Regresión Lineal para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = linreg_ridge.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, linreg_ridge.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, linreg_ridge.predict(x_test))}')
# Out:
# MAE:194.18132258205597
# MSE: 146470.5275347649

# %%
dump(linreg_ridge, 'modelos/ecoli_linreg_coyhaique.joblib')
# Out:
# ['modelos/ecoli_linreg_coyhaique.joblib']

# %% [markdown]
# ## RandomForest

# %%
rf = GridSearchCV(RandomForestRegressor(n_jobs = -1), cv = 10, param_grid = param_grid_rf).fit(x_train, y_train).best_estimator_

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de RandomForest para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = rf.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo RandomForest', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, rf.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, rf.predict(x_test))}')
# Out:
# MAE:184.32140277355143
# MSE: 140120.15400795863

# %%
dump(rf, 'modelos/ecoli_rf_coyhaique.joblib')
# Out:
# ['modelos/ecoli_rf_coyhaique.joblib']

# %% [markdown]
# ## AdaBoost

# %%
ada = GridSearchCV(MultiOutputRegressor(AdaBoostRegressor(), n_jobs = -1), cv = 10, param_grid = param_grid_ada).fit(x_train, y_train).best_estimator_

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de AdaBoost para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = ada.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo AdaBoost', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, ada.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, ada.predict(x_test))}')
# Out:
# MAE:186.4284338472829
# MSE: 166925.56259277

# %%
#dump(ada, 'modelos/ecoli_ada_coyhaique.joblib')
# Out:
# ['modelos/ecoli_ada_coyhaique.joblib']

# %% [markdown]
# ## XGBoost

# %%
xgboost = MultiOutputRegressor(xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 10, n_estimators = 100), n_jobs = -1)

# %%
xgboost.fit(x_train, y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(alpha=10, base_score=None,
#                                             booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.3,
#                                             enable_categorical=False,
#                                             gamma=None, gpu_id=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.1,
#                                             max_delta_step=None, max_depth=10,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
# ...

# %%
xgboost = load('modelos/ecoli_xgboost_coyhaique.joblib')

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de XGBoost para e-coli en las {len(y_test)} ultimas semanas de datos\n En la localidad de Coyhaique', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = xgboost.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo XGBoost', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
plt.xlabel('Fecha')
plt.ylabel('E-COLI')
sn.despine()
plt.savefig('img/resultados/xgboost_coyhaique_ecoli.png')

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
print(f'MSE: {mean_squared_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
# Out:
# MAE:156.0791563351949
# MSE: 41118.114772060304

# %%
#dump(xgboost, 'modelos/ecoli_xgboost_coyhaique.joblib')
# Out:
# ['modelos/ecoli_xgboost_coyhaique.joblib']

# %% [markdown]
# ## SARIMAX

# %%
ar_order = [1]
ma_order = [2]

diff_order = 1
test_size = 12

# %%
# %time

exog_series = x_train
endog_series = y_train.lag_0
rolling_predictions = []
test_size = 12

#for i in range(test_size):
#    exog_train = exog_series[:-(test_size-i)]
#    endog_train = endog_series[:-(test_size-i)]
#    model = SARIMAX(endog = endog_train, exog = exog_train ,order = (ar_order, diff_order, ma_order))
#    model_fit = model.fit(disp = False)
#    pred = model_fit.forecast(exog = exog_train[-1, :])# + res.seasonal[-1:].values
#    rolling_predictions.append(pred.values[0])#.append(np.sqrt(pred.variance.values[-1,:][0]))
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 4.77 µs

# %%
sarimax = SARIMAX(endog = y_train.lag_0.iloc[-3:], exog = x_train[-3:, :] ,order = (ar_order, diff_order, ma_order))
sarimax_fit = sarimax.fit(disp = False)

# %%
sarimax_fit = load('modelos/ecoli_SARIMAX_coyhaique.joblib')

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de SARIMAX para e-coli en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True).to_numpy(), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data =  sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy(), color = 'darkgreen', label = 'Predicciones Modelo SARIMAX', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
print(f'MSE: {mean_squared_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
# Out:
# MAE:119.63245764071037
# MSE: 38970.777784450846

# %%
#dump(sarimax_fit, 'modelos/ecoli_SARIMAX_coyhaique.joblib')
# Out:
# ['modelos/ecoli_SARIMAX_coyhaique.joblib']

# %% [markdown]
# ------

# %% [markdown]
# # Turbiedad

# %%
tain_test_format_results = generate_train_test(proc_data, target_col = 'TURBIEDAD')
x_train, x_test, y_train, y_test = tain_test_format_results['data']
scaler = tain_test_format_results['std_scaler']

# %%
#dump(scaler, 'modelos/turbiedad_scaler_coyhaique.joblib')
# Out:
# ['modelos/turbiedad_scaler_coyhaique.joblib']

# %% [markdown]
# ## Regresión lineal - Regularizada con Ridge

# %%
linreg_ridge = RidgeCV(cv = 5).fit(x_train, y_train)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de Regresión Lineal para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = linreg_ridge.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo Regresión Lineal', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, linreg_ridge.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, linreg_ridge.predict(x_test))}')
# Out:
# MAE:4.623887237249087
# MSE: 59.48812886502063

# %%
dump(linreg_ridge, 'modelos/turbiedad_linreg_coyhaique.joblib')
# Out:
# ['modelos/turbiedad_linreg_coyhaique.joblib']

# %% [markdown]
# ## RandomForest

# %%
rf = GridSearchCV(RandomForestRegressor(n_jobs = -1), cv = 10, param_grid = param_grid_rf).fit(x_train, y_train).best_estimator_

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de RandomForest para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = rf.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo RandomForest', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test, rf.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, rf.predict(x_test))}')
# Out:
# MAE:3.8710588725008765
# MSE: 67.49095620198264

# %%
dump(rf, 'modelos/turbiedad_rf_coyhaique.joblib')
# Out:
# ['modelos/turbiedad_rf_coyhaique.joblib']

# %% [markdown]
# ## AdaBoost

# %%
ada = GridSearchCV(MultiOutputRegressor(AdaBoostRegressor(), n_jobs = -1), cv = 10, param_grid = param_grid_ada).fit(x_train, y_train).best_estimator_

# %%
ada = load('modelos/turbiedad_ada_coyhaique.joblib')

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de AdaBoost para turbiedad en las {len(y_test)} ultimas semanas de datos\n Para la localidad de Coyhaique', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = ada.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo AdaBoost', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
plt.xlabel('Fecha')
plt.ylabel('Turbiedad')
sn.despine()
plt.savefig('img/resultados/adaboost_coyhaique_turbiedad.png')

# %%
print(f'MAE:{mean_absolute_error(y_test, ada.predict(x_test))}')
print(f'MSE: {mean_squared_error(y_test, ada.predict(x_test))}')
# Out:
# MAE:3.194873415389194
# MSE: 65.33165520235832

# %%
#dump(ada, 'modelos/turbiedad_ada_coyhaique.joblib')
# Out:
# ['modelos/turbiedad_ada_coyhaique.joblib']

# %% [markdown]
# ## XGBoost

# %%
xgboost = MultiOutputRegressor(xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 10, n_estimators = 100), n_jobs = -1)

# %%
xgboost.fit(x_train, y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(alpha=10, base_score=None,
#                                             booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.3,
#                                             enable_categorical=False,
#                                             gamma=None, gpu_id=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.1,
#                                             max_delta_step=None, max_depth=10,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
# ...

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de XGBoost para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data = xgboost.predict(x_test[0].reshape(-1, 18))[0], color = 'darkgreen', label = 'Predicciones Modelo XGBoost', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
print(f'MSE: {mean_squared_error(y_test.lag_0, xgboost.predict(x_test[0].reshape(-1, 18))[0])}')
# Out:
# MAE:5.15802896420161
# MSE: 122.74394053044269

# %%
dump(xgboost, 'modelos/turbiedad_xgboost_coyhaique.joblib')
# Out:
# ['modelos/turbiedad_xgboost_coyhaique.joblib']

# %% [markdown]
# ## SARIMAX

# %%
ar_order = [1]
ma_order = [2]

diff_order = 1
test_size = 12

# %%
# %time

exog_series = x_train
endog_series = y_train.lag_0
rolling_predictions = []
test_size = 12

#for i in range(test_size):
#    exog_train = exog_series[:-(test_size-i)]
#    endog_train = endog_series[:-(test_size-i)]
#    model = SARIMAX(endog = endog_train, exog = exog_train ,order = (ar_order, diff_order, ma_order))
#    model_fit = model.fit(disp = False)
#    pred = model_fit.forecast(exog = exog_train[-1, :])
#    rolling_predictions.append(pred.values[0])
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs

# %%
sarimax = SARIMAX(endog = y_train.lag_0.iloc[-3:], exog = x_train[-3:, :] ,order = (ar_order, diff_order, ma_order))
sarimax_fit = sarimax.fit(disp = False)

# %%
plt.subplots(figsize = (15,7))
plt.title(f'Predicciones Modelo de SARIMAX para turbiedad en las {len(y_test)} ultimas semanas de datos', size = 15)
sn.lineplot(data = y_test.lag_0.reset_index(drop=True).to_numpy(), label = 'Datos reales', color = 'dodgerblue', marker = 'o')
sn.lineplot(data =  sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy(), color = 'darkgreen', label = 'Predicciones Modelo SARIMAX', marker = 'o')
plt.xticks(ticks = range(len(y_test)), labels = y_test.reset_index().fecha_muestra.dt.date, rotation = 45)
sn.despine();

# %%
print(f'MAE:{mean_absolute_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
print(f'MSE: {mean_squared_error(y_test.lag_0, sarimax_fit.forecast(exog = x_train[-12:, :], steps = 12).to_numpy())}')
# Out:
# MAE:4.233343293243109
# MSE: 120.48314827959824

# %%
dump(SARIMAX, 'modelos/turbiedad_SARIMAX_coyhaique.joblib')
# Out:
# ['modelos/turbiedad_SARIMAX_coyhaique.joblib']
